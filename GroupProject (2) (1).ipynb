# %%
#import the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading the dataset (downloaded the dataset from kaggle.com)
#https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud
df = pd.read_csv('creditcard.csv')
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
#There is no null values.

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
#To find the correlation.
df.corr()
# Out:
#             Time            V1            V2            V3            V4  \
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1      0.117396  1.000000e+00  4.135835e-16 -1.227819e-15 -9.215150e-16
# V2     -0.010593  4.135835e-16  1.000000e+00  3.243764e-16 -1.121065e-15
# V3     -0.419618 -1.227819e-15  3.243764e-16  1.000000e+00  4.711293e-16
# V4     -0.105260 -9.215150e-16 -1.121065e-15  4.711293e-16  1.000000e+00
# V5      0.173072  1.812612e-17  5.157519e-16 -6.539009e-17 -1.719944e-15
# V6     -0.063016 -6.506567e-16  2.787346e-16  1.627627e-15 -7.491959e-16
# V7      0.084714 -1.005191e-15  2.055934e-16  4.895305e-16 -4.104503e-16
# V8     -0.036949 -2.433822e-16 -5.377041e-17 -1.268779e-15  5.697192e-16
# V9     -0.008660 -1.513678e-16  1.978488e-17  5.568367e-16  6.923247e-16
# V10     0.030617  7.388135e-17 -3.991394e-16  1.156587e-15  2.232685e-16
# V11    -0.247689  2.125498e-16  1.975426e-16  1.576830e-15  3.459380e-16
# ...

# %%
#To plot the correlation
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
#To find the shape
df.shape
# Out:
# (284807, 31)

# %%
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
# 0 represents normal transaction and 1 represents fraud transactions

# %%
#To drop the time column
df = df.drop(['Time'],axis=1, inplace=True)

# %%
df
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V21       V22  \
# ...

# %%
#Exploratory data analysis
sns.countplot(x = df['Class'])
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %%
#The data is imbalenced.

# %%
#So we divide the transactions into normal transaction and fraud transactions
normal = df[df['Class']==0]
fraud = df[df['Class']==1]

# %%
normal.shape
# Out:
# (284315, 30)

# %%
fraud.shape
# Out:
# (492, 30)

# %%
#There are 284315 transactions. We randomly choose 492 transactions.
normal_sample = normal.sample(n=492)
normal_sample
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 82289   0.763864 -1.040710  0.894537  0.429939 -1.357151 -0.281505 -0.292919
# 228604  2.054288 -0.118125 -1.439832  0.185625  0.098481 -0.883473  0.088726
# 179397  1.937071 -1.059011 -0.880942 -0.481155 -0.728636 -0.151782 -0.634517
# 151912 -3.150359 -2.943361  0.023627  3.261232 -2.139054  5.990176  4.643250
# 147948  1.283403 -1.271557 -1.664122  0.714106 -0.345384 -0.945601  0.753856
# ...          ...       ...       ...       ...       ...       ...       ...
# 237765  1.964153 -0.072185 -1.678609  0.520992  0.266845 -1.294745  0.678733
# 167265  1.940607  0.062633 -2.214651  0.966422  1.017684 -0.403627  0.685409
# 68110   1.216990 -1.796740  1.609769 -0.969952 -2.246240  0.991015 -2.039409
# 1621    1.291489  0.253127 -0.412977  0.115805  0.771362  0.726515 -0.087619
# 150478 -1.624495  0.196130  1.982783  4.715447  1.493214  1.513188 -0.461528
#
# ...

# %%
#concatenating two dataframes normal_sample and fraud. 
df1 = pd.concat([normal_sample,fraud],axis = 0)

# %%
df1['Class'].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
# Separating independent variable and dependent variable
X = df1.iloc[:,:-1].values
Y = df1.iloc[:,-1].values

# %%
#Feature scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
df['Amount'] = sc.fit_transform(pd.DataFrame(df['Amount']))

# %%
#separating training and testing data
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (787, 29)
# (787,)
# (197, 29)
# (197,)

# %%
#To find the best value for K
x = []
y = []
for i in range(1,35,2):
    knn = KNeighborsClassifier(n_neighbors=i)
    score = cross_val_score(knn,X_train,Y_train,cv=5)
    x.append(i)
    y.append(max(score))

# %%
plt.plot(x,y)
plt.grid()
plt.show()

# %%
#To find the best value for K
x_t = []
y_t = []
for i in range(1,35,2):
    knn = KNeighborsClassifier(n_neighbors=i)
    score = cross_val_score(knn,X_test,Y_test,cv=5)
    x_t.append(i)
    y_t.append(max(score))

# %%
plt.plot(x_t,y_t)
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 plt.plot(x_t,y_t)
#       2 plt.grid()
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
#The best value for K is 3

# %%
#K-Nearest Neighbour
from sklearn.neighbours import KNeighbourClassifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train,Y_train)

# %%
Y_predict = knn.predict(X_test)

# %%
#Confusion matrix
from sklearn.matrix import confusion_matrix
print(confusion_matrix(Y_test,Y_predict))
# Out:
# [[86  9]
#  [13 89]]

# %%
#Classification report
from sklearn.matrix import classification_report
print(classification_report(Y_test,Y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89        95
#            1       0.91      0.87      0.89       102
#
#     accuracy                           0.89       197
#    macro avg       0.89      0.89      0.89       197
# weighted avg       0.89      0.89      0.89       197

# %%
#Cross Validation
from sklearn.model_selection import cross_val_score
cross_val_score(knn,X_test,Y_test,cv=5)
# Out:
# array([0.825     , 0.7       , 0.87179487, 0.92307692, 0.74358974])

# %%
cross_val_score(knn,X_train,Y_train,cv=5)
# Out:
# array([0.86708861, 0.91772152, 0.92993631, 0.9044586 , 0.92993631])
